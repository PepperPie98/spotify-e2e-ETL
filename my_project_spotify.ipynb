# %%
# !pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
client_credentials_manager=SpotifyClientCredentials(client_id="d9e4c6e112de499db507afe3c6144693", client_secret="b9e27dfc7a7d4555932e4dd80047d96e")

# %%
sp= spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/3IsxzDS04BvejFJcQ0iVyW"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data= sp.playlist_tracks(playlist_URI)

# %%
#for one album
data['items'][0]['track']['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#    'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#    'id': '5cj0lLjcoR7YOSnhnX0Po5',
#    'name': 'Doja Cat',
#    'type': 'artist',
#    'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '54dZypaXHAIDzBe9ujAZ63'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Paint The Town Red'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-08-04'

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/54dZypaXHAIDzBe9ujAZ63'}

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date =row['track']['album']['release_date']
    album_url=row['track']['album']['external_urls']
    album_elements = {'album_id': album_id,'album_name' :album_name,'album_release_date':album_release_date,'album_url':album_url}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '54dZypaXHAIDzBe9ujAZ63',
#   'album_name': 'Paint The Town Red',
#   'album_release_date': '2023-08-04',
#   'album_url': {'spotify': 'https://open.spotify.com/album/54dZypaXHAIDzBe9ujAZ63'}},
#  {'album_id': '6PbnGueEO6LGodPfvNldYf',
#   'album_name': 'Zach Bryan',
#   'album_release_date': '2023-08-25',
#   'album_url': {'spotify': 'https://open.spotify.com/album/6PbnGueEO6LGodPfvNldYf'}},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'album_release_date': '2023-09-08',
#   'album_url': {'spotify': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'album_release_date': '2023-09-08',
#   'album_url': {'spotify': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'album_release_date': '2023-09-08',
#   'album_url': {'spotify': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'}},
# ...

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict =  {'artist_id' : artist['id'], 'artist_name': artist['name']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5cj0lLjcoR7YOSnhnX0Po5', 'artist_name': 'Doja Cat'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2', 'artist_name': 'Zach Bryan'},
#  {'artist_id': '70kkdajctXSbqSMJbQO424', 'artist_name': 'Kacey Musgraves'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG', 'artist_name': 'Olivia Rodrigo'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG', 'artist_name': 'Olivia Rodrigo'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG', 'artist_name': 'Olivia Rodrigo'},
#  {'artist_id': '2hlmm7s2ICUX0LVIhVFlZQ', 'artist_name': 'Gunna'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG', 'artist_name': 'Olivia Rodrigo'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG', 'artist_name': 'Olivia Rodrigo'},
#  {'artist_id': '6HaGTQPmzraVmaVxvz6EUc', 'artist_name': 'Jung Kook'},
#  {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ', 'artist_name': 'Latto'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02', 'artist_name': 'Taylor Swift'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP', 'artist_name': 'SZA'},
#  {'artist_id': '6IkfE2JyVoKwBZXvuytKX3',
# ...

# %%
import pandas as pd

# %%
album_df = pd.DataFrame.from_dict(album_list)
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
album_df.head()
# Out:
#                  album_id          album_name album_release_date  \
# 0  54dZypaXHAIDzBe9ujAZ63  Paint The Town Red         2023-08-04
# 1  6PbnGueEO6LGodPfvNldYf          Zach Bryan         2023-08-25
# 2  1xJHno7SmdVtZAtXbdbDZp                GUTS         2023-09-08
# 3  1xJHno7SmdVtZAtXbdbDZp                GUTS         2023-09-08
# 4  1xJHno7SmdVtZAtXbdbDZp                GUTS         2023-09-08
#
#                                            album_url
# 0  {'spotify': 'https://open.spotify.com/album/54...
# 1  {'spotify': 'https://open.spotify.com/album/6P...
# 2  {'spotify': 'https://open.spotify.com/album/1x...
# 3  {'spotify': 'https://open.spotify.com/album/1x...
# 4  {'spotify': 'https://open.spotify.com/album/1x...

# %%
#  album_df['album_release_date']= pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            99 non-null     object
#  1   album_name          99 non-null     object
#  2   album_release_date  99 non-null     object
#  3   album_url           99 non-null     object
# dtypes: object(4)
# memory usage: 3.2+ KB

# %%
album_df['album_release_date']
# Out:
# 0     2023-08-04
# 1     2023-08-25
# 2     2023-09-08
# 3     2023-09-08
# 4     2023-09-08
#          ...
# 94    2017-03-18
# 95    2023-07-28
# 96          2009
# 97    2022-05-06
# 98    2010-11-26
# Name: album_release_date, Length: 99, dtype: object

# %%
artist_df
# Out:
#                   artist_id      artist_name
# 0    5cj0lLjcoR7YOSnhnX0Po5         Doja Cat
# 1    40ZNYROS4zLfyyBSs2PGe2       Zach Bryan
# 2    70kkdajctXSbqSMJbQO424  Kacey Musgraves
# 3    1McMsnEElThX1knmY4oliG   Olivia Rodrigo
# 4    1McMsnEElThX1knmY4oliG   Olivia Rodrigo
# ..                      ...              ...
# 134  53KwLdlmrlCelAZMaLVZqU      James Blake
# 135  1URnnhqYAYcrqrcwql10ft        21 Savage
# 136  3TVXtAsR1Inumwj472S9r4            Drake
# 137  4q3ewBCX7sLwd24euuV69X        Bad Bunny
# 138  360IAlyVv4PCEVjgyMZrxK           Miguel
#
# [139 rows x 2 columns]

# %%
album_df
# Out:
#                   album_id          album_name album_release_date  \
# 0   54dZypaXHAIDzBe9ujAZ63  Paint The Town Red         2023-08-04
# 1   6PbnGueEO6LGodPfvNldYf          Zach Bryan         2023-08-25
# 2   1xJHno7SmdVtZAtXbdbDZp                GUTS         2023-09-08
# 3   1xJHno7SmdVtZAtXbdbDZp                GUTS         2023-09-08
# 4   1xJHno7SmdVtZAtXbdbDZp                GUTS         2023-09-08
# ..                     ...                 ...                ...
# 94  1lXY618HWkwYKJWBRYR4MK           More Life         2017-03-18
# 95  18NOKLkZETa4sWwLMIm0UZ              UTOPIA         2023-07-28
# 96  1LShhEEKRT5MNPcO7jtYHh         So Far Gone               2009
# 97  3RQQmkQEvNCY4prGKE6oc5    Un Verano Sin Ti         2022-05-06
# 98  493HYe7N5pleudEZRyhE7R   All I Want Is You         2010-11-26
#
#                                             album_url
# 0   {'spotify': 'https://open.spotify.com/album/54...
# 1   {'spotify': 'https://open.spotify.com/album/6P...
# ...
